# %%
import cv2
import numpy as np

# %%
folder_name = "augmented_image"
extension = ".jpg"

# %%
def flip_image(image,dir):
  image = cv2.flip(image,dir)
  cv2.imwrite(folder_name+"/flip-"+str(dir)+extension, image)

# %%
def sharpen_image(image):
    kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
    image = cv2.filter2D(image,-1, kernel)
    cv2.imwrite(folder_name+"/sharpen-"+extension, image)

# %%
def rotate_image(image, deg):
  rows, cols,c =image.shape
  M = cv2.getRotationMatrix2D((cols/2,rows/2),deg,1)
  image = cv2.warpAffine(image,M,(cols,rows))
  cv2.imwrite(folder_name+"/rotate-"+extension,image)

# %%
def Brighten_image(image):
  M = np.ones(image.shape,dtype = 'uint8')*75
  image = cv2.add(image,M)
  cv2.imwrite(folder_name+"/brighten-"+extension,image)

# %%
def reduced_Brighten_image(image):
  M = np.ones(image.shape,dtype = 'uint8')*75
  image = cv2.subtract(image,M)
  cv2.imwrite(folder_name+"/reduced_brighten-"+extension,image)

# %%
import cv2
import os
import glob
img_dir = "Amazon_webscraping/Train/men_jean" # Enter Directory of all images 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1)
    data.append(img)

# %%
os.mkdir('augmented_image')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-36-fc0929ed9d96> in <module>
# ----> 1 os.mkdir('augmented_image')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'augmented_image'

# %%
len(data)
# Out:
# 90

# %%
data
# Out:
# [array([[[255, 254, 254],
#          [ 58,  48,  48],
#          [ 49,  35,  36],
#          ...,
#          [ 44,  33,  35],
#          [ 21,  15,  16],
#          [225, 220, 221]],
#
#         [[255, 254, 254],
#          [ 57,  47,  47],
#          [ 51,  37,  38],
#          ...,
#          [ 25,  14,  16],
#          [101,  95,  96],
#          [255, 251, 252]],
#
#         [[255, 254, 254],
#          [ 55,  45,  45],
#          [ 54,  40,  41],
#          ...,
#          [ 35,  24,  26],
#          [205, 199, 200],
#          [255, 254, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
augmented_image = []
for img in data:
    img1=sharpen_image(img)
    img2 =Brighten_image(i
    img3 = reduced_Brighten_image(img)
    img4 = flip_image(img,1)
    img5 = rotate_image(img, 30)
    img6 = rotate_image(img, -30)
    
    augmented_image.append(img1)
    augmented_image.append(img2)
    augmented_image.append(img3)
    augmented_image.append(img4)
    augmented_image.append(img5)
    augmented_image.append(img6)

# %%
len(augmented_image)
# Out:
# 540

# %%
augmented_image
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
